# %% [markdown]
# ## Data Cleaning for reviews.csv

# %%
# Dependencies and packages
# %reload_ext lab_black

import os
import pandas as pd
import numpy as np
import math as math

# %%
# Read Reviews CSV
csv_path = os.path.join("../data/csv/reviews.csv")
df_reviews = pd.read_csv(csv_path)

# %%
df_reviews.head()
# Out:
#    beer_id         username        date  \
# 0   271781     bluejacket74  2017-03-17
# 1   125646          _dirty_  2017-12-21
# 2   125646          CJDUBYA  2017-12-21
# 3   125646  GratefulBeerGuy  2017-12-20
# 4   125646         LukeGude  2017-12-20
#
#                                                 text  look  smell  taste  \
# 0     750 ml bottle, 2016 vintage, bottle #304 of...  4.00   4.00   4.00
# 1                                                     4.50   4.50   4.50
# 2                                                     4.75   4.75   4.75
# 3     0% 16 oz can. Funny story: As I finally wal...  4.75   4.75   4.50
# 4     Classic TH NEIPA. Overflowing head and bouq...  4.25   4.50   4.25
#
#    feel  overall  score
# 0  4.25     4.00   4.03
# 1  4.50     4.50   4.50
# 2  4.75     4.75   4.75
# 3  4.50     4.50   4.58
# 4  4.25     4.25   4.31

# %%
# Find the DF size pre-cleaning
print(df_reviews.shape)
# Out:
# (9073128, 10)

# %%
# Find the number of unique beers in reviews.csv
df_reviews["beer_id"].value_counts()
# Out:
# 11757     17160
# 2093      15947
# 7971      14927
# 1093      14915
# 29619     14292
#           ...
# 203777        1
# 126326        1
# 109950        1
# 282050        1
# 8188          1
# Name: beer_id, Length: 309542, dtype: int64

# %%
# Find unique users who reviewed
df_reviews["username"].value_counts()

# %%
# Find value counts for every column in reviews.csv
df_reviews.apply(lambda x: x.isnull().value_counts())
# Out:
#          beer_id  username       date       text     look    smell    taste  \
# False  9073128.0   9069313  9073128.0  9073128.0  5283110  5283110  5283110
# True         NaN      3815        NaN        NaN  3790018  3790018  3790018
#
#           feel  overall      score
# False  5283110  5283110  9073128.0
# True   3790018  3790018        NaN

# %%
df_clean = df_reviews.copy()

# %%
# Delete all the beers that have less than 100 reviews
df_clean = df_clean[df_clean.groupby("beer_id").beer_id.transform("count") > 100].copy()
df_clean.head()
# Out:
#    beer_id         username        date  \
# 1   125646          _dirty_  2017-12-21
# 2   125646          CJDUBYA  2017-12-21
# 3   125646  GratefulBeerGuy  2017-12-20
# 4   125646         LukeGude  2017-12-20
# 5   125646          jneff33  2017-12-20
#
#                                                 text  look  smell  taste  \
# 1                                                     4.50   4.50   4.50
# 2                                                     4.75   4.75   4.75
# 3     0% 16 oz can. Funny story: As I finally wal...  4.75   4.75   4.50
# 4     Classic TH NEIPA. Overflowing head and bouq...  4.25   4.50   4.25
# 5                                                     4.50   4.75   5.00
#
#    feel  overall  score
# 1  4.50     4.50   4.50
# 2  4.75     4.75   4.75
# 3  4.50     4.50   4.58
# 4  4.25     4.25   4.31
# 5  5.00     5.00   4.91

# %%
# The algorithm below reduces the memory size of a dataframe
def reduce_mem_usage(props):
    start_mem_usg = props.memory_usage().sum() / 1024 ** 2
    print("Memory usage of properties dataframe is :", start_mem_usg, " MB")
    NAlist = []  # Keeps track of columns that have missing values filled in.
    for col in props.columns:
        if props[col].dtype != object:  # Exclude strings

            # Print current column type
            print("******************************")
            print("Column: ", col)
            print("dtype before: ", props[col].dtype)

            # make variables for Int, max and min
            IsInt = False
            mx = props[col].max()
            mn = props[col].min()

            # Integer does not support NA, therefore, NA needs to be filled
            if not np.isfinite(props[col]).all():
                NAlist.append(col)
                props[col].fillna(mn - 1, inplace=True)

            # test if column can be converted to an integer
            asint = props[col].fillna(0).astype(np.int64)
            result = props[col] - asint
            result = result.sum()
            if result > -0.01 and result < 0.01:
                IsInt = True

            # Make Integer/unsigned Integer datatypes
            if IsInt:
                if mn >= 0:
                    if mx < 255:
                        props[col] = props[col].astype(np.uint8)
                    elif mx < 65535:
                        props[col] = props[col].astype(np.uint16)
                    elif mx < 4294967295:
                        props[col] = props[col].astype(np.uint32)
                    else:
                        props[col] = props[col].astype(np.uint64)
                else:
                    if mn > np.iinfo(np.int8).min and mx < np.iinfo(np.int8).max:
                        props[col] = props[col].astype(np.int8)
                    elif mn > np.iinfo(np.int16).min and mx < np.iinfo(np.int16).max:
                        props[col] = props[col].astype(np.int16)
                    elif mn > np.iinfo(np.int32).min and mx < np.iinfo(np.int32).max:
                        props[col] = props[col].astype(np.int32)
                    elif mn > np.iinfo(np.int64).min and mx < np.iinfo(np.int64).max:
                        props[col] = props[col].astype(np.int64)

            # Make float datatypes 32 bit
            else:
                props[col] = props[col].astype(np.float32)

            # Print new column type
            print("dtype after: ", props[col].dtype)
            print("******************************")

    # Print final result
    print("___MEMORY USAGE AFTER COMPLETION:___")
    mem_usg = props.memory_usage().sum() / 1024 ** 2
    print("Memory usage is: ", mem_usg, " MB")
    print("This is ", 100 * mem_usg / start_mem_usg, "% of the initial size")
    return props, NAlist

# %%
# Check Memory Usage
props = df_clean
props, NAlist = reduce_mem_usage(props)
print("_________________")
print("")
print(
    "Warning: the following columns have missing values filled with 'df['column_name'].min() -1': "
)
print("_________________")
print("")
print(NAlist)
# Out:
# Memory usage of properties dataframe is : 568.8571548461914  MB
# ******************************
# Column:  beer_id
# dtype before:  int64
# dtype after:  uint32
# ******************************
# ******************************
# Column:  look
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  smell
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  taste
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  feel
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  overall
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  score
# dtype before:  float64
# dtype after:  float32
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  387.85715103149414  MB
# This is  68.18181818181819 % of the initial size
# _________________
#
# Warning: the following columns have missing values filled with 'df['column_name'].min() -1':
# _________________
#
# ['look', 'smell', 'taste', 'feel', 'overall']

# %%
df_clean = props.copy()

# %%
df_clean.head()
# Out:
#    beer_id         username        date  \
# 1   125646          _dirty_  2017-12-21
# 2   125646          CJDUBYA  2017-12-21
# 3   125646  GratefulBeerGuy  2017-12-20
# 4   125646         LukeGude  2017-12-20
# 5   125646          jneff33  2017-12-20
#
#                                                 text  look  smell  taste  \
# 1                                                     4.50   4.50   4.50
# 2                                                     4.75   4.75   4.75
# 3     0% 16 oz can. Funny story: As I finally wal...  4.75   4.75   4.50
# 4     Classic TH NEIPA. Overflowing head and bouq...  4.25   4.50   4.25
# 5                                                     4.50   4.75   5.00
#
#    feel  overall  score
# 1  4.50     4.50   4.50
# 2  4.75     4.75   4.75
# 3  4.50     4.50   4.58
# 4  4.25     4.25   4.31
# 5  5.00     5.00   4.91

# %%
# Drop unwanted columns
df_clean = df_clean.drop(["date", "look", "smell", "taste", "feel", "overall"], axis=1)

# %%
df_clean.head()
# Out:
#    beer_id         username  \
# 1   125646          _dirty_
# 2   125646          CJDUBYA
# 3   125646  GratefulBeerGuy
# 4   125646         LukeGude
# 5   125646          jneff33
#
#                                                 text  score
# 1                                                      4.50
# 2                                                      4.75
# 3     0% 16 oz can. Funny story: As I finally wal...   4.58
# 4     Classic TH NEIPA. Overflowing head and bouq...   4.31
# 5                                                      4.91

# %%
df_clean.dtypes
# Out:
# beer_id      uint32
# username     object
# text         object
# score       float32
# dtype: object

# %%
# list comprehension to strip each row
df_clean["text"] = [x.strip(" \xa0") for x in df_clean["text"]]

# %%
df_clean = df_clean[df_clean["text"] != ""]

# %%
df_clean
# Out:
#          beer_id         username  \
# 3         125646  GratefulBeerGuy
# 4         125646         LukeGude
# 7         125646             MFMB
# 13        125646      jngrizzaffi
# 15        125646         PDOR1960
# ...          ...              ...
# 9073095    58482           smcolw
# 9073096    58482    firkinhophead
# 9073097    58482          CHADMC3
# 9073110   104824     zookerman182
# 9073114   104824        Hesscabob
#
#                                                       text  score
# 3        0% 16 oz can. Funny story: As I finally walked...   4.58
# 4        Classic TH NEIPA. Overflowing head and bouquet...   4.31
# 7        Pours a creamy opaque light straw yellow with ...   4.52
# 13       Pours a cloudy yellow color with a thin foamy ...   4.53
# 15                     Another great brew from Treehouse!!   4.50
# ...                                                    ...    ...
# 9073095  Large chalky white head. Leaves lots of spotty...   3.58
# 9073096  pours a hazy, almost cloudy, autumn gold. Appa...   3.92
# 9073097  Pours a hazy golden/orange to copper with a bi...   3.80
# 9073110  Appearance is dark dark brown with a half fing...   4.35
# 9073114  Shared botte. A - Murky, brown, hardly any lig...   4.67
#
# [2199604 rows x 4 columns]

# %%
# Read Beers CSV
csv_path2 = os.path.join("../data/csv/beers.csv")
df_beers = pd.read_csv(csv_path2)

# %%
df_beers = df_beers.rename(columns={"id": "beer_id"})

# %%
# Merge the two dataframe
final_df = pd.merge(df_clean, df_beers[["beer_id", "name", "style"]], on="beer_id")
final_df.head()
# Out:
#    beer_id         username  \
# 0   125646  GratefulBeerGuy
# 1   125646         LukeGude
# 2   125646             MFMB
# 3   125646      jngrizzaffi
# 4   125646         PDOR1960
#
#                                                 text  score  name  \
# 0  0% 16 oz can. Funny story: As I finally walked...   4.58  Haze
# 1  Classic TH NEIPA. Overflowing head and bouquet...   4.31  Haze
# 2  Pours a creamy opaque light straw yellow with ...   4.52  Haze
# 3  Pours a cloudy yellow color with a thin foamy ...   4.53  Haze
# 4                Another great brew from Treehouse!!   4.50  Haze
#
#              style
# 0  New England IPA
# 1  New England IPA
# 2  New England IPA
# 3  New England IPA
# 4  New England IPA

# %%
final_df = final_df.dropna(how="any", axis=0)

# %%
final_df.to_csv(os.path.join("../data/csv/reviews_NLTK.csv"))

# %%
final_df["beer_id"].value_counts()
# Out:
# 645       4364
# 11757     4300
# 2093      4252
# 7971      4155
# 1093      4054
#           ...
# 78122        6
# 124684       5
# 108184       5
# 111083       5
# 138902       4
# Name: beer_id, Length: 12533, dtype: int64

# %%
# We now have 12533 unique beers instead of 309542 prior cleaning.

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2199604 entries, 0 to 2199603
# Data columns (total 6 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   beer_id   uint32
#  1   username  object
#  2   text      object
#  3   score     float32
#  4   name      object
#  5   style     object
# dtypes: float32(1), object(4), uint32(1)
# memory usage: 100.7+ MB

# %%
final_df.apply(lambda x: x.isnull().value_counts())
# Out:
#        beer_id  username     text    score     name    style
# False  2196268   2196268  2196268  2196268  2196268  2196268

# %% [markdown]
# ## BEGIN HERE For further work using this final csv file.
# This is to save time re-running the whole notebook.

# %%
# Reloading
path = os.path.join("../data/csv/reviews_NLTK.csv")
df = pd.read_csv(path)

# %%
df.drop("Unnamed: 0", axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-729b4bce6bc7> in <module>
# ----> 1 df.drop("Unnamed: 0", axis=1, inplace=True)
#
# ~/.local/share/virtualenvs/ALE-gorithm-II-YmYK28KK/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# ~/.local/share/virtualenvs/ALE-gorithm-II-YmYK28KK/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ~/.local/share/virtualenvs/ALE-gorithm-II-YmYK28KK/lib/python3.8/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# ~/.local/share/virtualenvs/ALE-gorithm-II-YmYK28KK/lib/python3.8/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5015         if mask.any():
#    5016             if errors != "ignore":
# -> 5017                 raise KeyError(f"{labels[mask]} not found in axis")
#    5018             indexer = indexer[~mask]
#    5019         return self.delete(indexer)
#
# KeyError: "['Unnamed: 0'] not found in axis"

# %%
df.to_csv("../data/csv/reviews_NLTK.csv", index=False)

# %%
df.shape

# %%
df["beer_id"].value_counts()

# %%
df = df[df.groupby("beer_id").beer_id.transform("count") > 300].copy()
df["beer_id"].value_counts()
# Out:
# 645       4355
# 11757     4277
# 2093      4231
# 7971      4137
# 1093      4035
#           ...
# 149331     301
# 3347       301
# 1506       301
# 1332       301
# 34129      301
# Name: beer_id, Length: 1686, dtype: int64

# %%
df.shape
# Out:
# (1255440, 6)

# %%
df
# Out:
#          beer_id         username  \
# 0         125646  GratefulBeerGuy
# 1         125646         LukeGude
# 2         125646             MFMB
# 3         125646      jngrizzaffi
# 4         125646         PDOR1960
# ...          ...              ...
# 1255435   251571            Zorro
# 1255436   251571    MichaelRabdau
# 1255437   251571         JohnnyMc
# 1255438   251571      Belekinbeer
# 1255439   251571      kylegillick
#
#                                                       text  score  \
# 0        0% 16 oz can. Funny story: As I finally walked...   4.58
# 1        Classic TH NEIPA. Overflowing head and bouquet...   4.31
# 2        Pours a creamy opaque light straw yellow with ...   4.52
# 3        Pours a cloudy yellow color with a thin foamy ...   4.53
# 4                      Another great brew from Treehouse!!   4.50
# ...                                                    ...    ...
# 1255435  Clear amber colored ale with a good sized whit...   3.52
# 1255436  A perfect companion and complement to Torpedo,...   5.00
# 1255437  Pours a clear golden color. Aroma is grapefrui...   3.31
# 1255438  I had this yesterday at SN Mills River. Grante...   4.35
# 1255439  Solid IPA with a good feel. Nothing too specia...   3.63
#
#                                   name            style
# 0                                 Haze  New England IPA
# 1                                 Haze  New England IPA
# 2                                 Haze  New England IPA
# 3                                 Haze  New England IPA
# 4                                 Haze  New England IPA
# ...                                ...              ...
# 1255435  Tropical Torpedo Tropical IPA     American IPA
# 1255436  Tropical Torpedo Tropical IPA     American IPA
# 1255437  Tropical Torpedo Tropical IPA     American IPA
# 1255438  Tropical Torpedo Tropical IPA     American IPA
# 1255439  Tropical Torpedo Tropical IPA     American IPA
#
# [1255440 rows x 6 columns]

# %%
df = df.groupby("beer_id", as_index=False).apply(
    lambda x: x[x.text.str.len() == x.text.str.len().max()]
)

# %%
df.shape
# Out:
# (1686, 6)

# %%
df.to_csv(os.path.join("../data/csv/reviews_NLTK1686.csv"), index=False)

# %%
df
# Out:
#               beer_id           username  \
# 0    49451          5      woodychandler
# 1    50061          6      rickyleepotts
# 2    51264          7            Jadjunk
# 3    52504         10          bditty187
# 4    53177         17        mikesgroove
# ...               ...                ...
# 1681 1166109   191070  transitionbikes93
# 1682 1188196   197183      woodychandler
# 1683 904882    202078           fmccormi
# 1684 1255228   251571      woodychandler
# 1685 23020     317146        THANAT0PSIS
#
#                                                            text  score  \
# 0    49451    I feel as though The CANQuest (TM) is once mor...   4.13
# 1    50061    I have had this beer before, and all I can rem...   2.96
# 2    51264    #115. I haven't reviewed much by Abita Brewing...   3.67
# 3    52504    From notes
#  Batch #29 Dark brown in hue, damn ...   3.86
# 4    53177    So, going to Grandmas for dinner tonight, and...   3.78
# ...                                                         ...    ...
# 1681 1166109  I dont know why this beer gets such a harsh ra...   4.88
# 1682 1188196  One of the great joys of The CANQuest (tm) is ...   4.37
# 1683 904882   Straight pour from a pry-off 12oz bottle to an...   4.44
# 1684 1255228  My unplanned SN horizontal reaches its conclus...   4.14
# 1685 23020    Sierra Nevada Hazy Little Thing A: Sierra Neva...   3.99
#
#                                        name                         style
# 0    49451                            Amber                  Vienna Lager
# 1    50061                         Turbodog             English Brown Ale
# 2    51264                      Purple Haze          Fruit and Field Beer
# 3    52504                       Dubbel Ale                Belgian Dubbel
# 4    53177                Widmer Hefeweizen             German Hefeweizen
# ...                                     ...                           ...
# 1681 1166109             Guinness Nitro IPA  English India Pale Ale (IPA)
# 1682 1188196       Citradelic Tangerine IPA                  American IPA
# 1683 904882         Enjoy By Unfiltered IPA         American Imperial IPA
# 1684 1255228  Tropical Torpedo Tropical IPA                  American IPA
# 1685 23020            Hazy Little Thing IPA               New England IPA
#
# [1686 rows x 6 columns]

# %% [markdown]
# #### Cleaning Methodology until this point:
# 1. Beers with less than 300 reviews
# 2. Duplicated beers - Essentially keeping 1 review text for each beer.
