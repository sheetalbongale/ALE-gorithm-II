# %%
import os
import numpy as np
import pandas as pd

# %%
beer_pickel_path = os.path.join('../data/dump/beer_final.pkl')

# %%
beers_df = pd.read_pickle(beer_pickel_path)

# %%
beers_df.head()
# Out:
#    beer_id     score         name                 style  brewery_id  \
# 0        5  3.403365        Amber          Vienna Lager           3
# 1        6  3.637484     Turbodog     English Brown Ale           3
# 2        7  3.221242  Purple Haze  Fruit and Field Beer           3
# 3     1565  3.493586    Andygator        German Maibock           3
# 4    39390  3.354275  Jockamo IPA          American IPA           3
#
#         brewery_name           city state country  \
# 0  Abita Brewing Co.  Abita Springs    LA      US
# 1  Abita Brewing Co.  Abita Springs    LA      US
# 2  Abita Brewing Co.  Abita Springs    LA      US
# 3  Abita Brewing Co.  Abita Springs    LA      US
# 4  Abita Brewing Co.  Abita Springs    LA      US
#
#                      beer_brewery
# 0        Amber; Abita Brewing Co.
# 1     Turbodog; Abita Brewing Co.
# 2  Purple Haze; Abita Brewing Co.
# 3    Andygator; Abita Brewing Co.
# 4  Jockamo IPA; Abita Brewing Co.

# %%
beers_df['beer_brewery'] = beers_df['beer_brewery'].replace(';', '-', regex=True)

# %%
beers_df.head()
# Out:
#    beer_id     score         name                 style  brewery_id  \
# 0        5  3.403365        Amber          Vienna Lager           3
# 1        6  3.637484     Turbodog     English Brown Ale           3
# 2        7  3.221242  Purple Haze  Fruit and Field Beer           3
# 3     1565  3.493586    Andygator        German Maibock           3
# 4    39390  3.354275  Jockamo IPA          American IPA           3
#
#         brewery_name           city state country  \
# 0  Abita Brewing Co.  Abita Springs    LA      US
# 1  Abita Brewing Co.  Abita Springs    LA      US
# 2  Abita Brewing Co.  Abita Springs    LA      US
# 3  Abita Brewing Co.  Abita Springs    LA      US
# 4  Abita Brewing Co.  Abita Springs    LA      US
#
#                      beer_brewery
# 0        Amber- Abita Brewing Co.
# 1     Turbodog- Abita Brewing Co.
# 2  Purple Haze- Abita Brewing Co.
# 3    Andygator- Abita Brewing Co.
# 4  Jockamo IPA- Abita Brewing Co.

# %%
beers_df['beer_brewery'] = beers_df['beer_brewery'].replace('/', '-', regex=True)

# %%
beers_df.head(-10)
# Out:
#       beer_id     score                       name                     style  \
# 0           5  3.403365                      Amber              Vienna Lager
# 1           6  3.637484                   Turbodog         English Brown Ale
# 2           7  3.221242                Purple Haze      Fruit and Field Beer
# 3        1565  3.493586                  Andygator            German Maibock
# 4       39390  3.354275                Jockamo IPA              American IPA
# ...       ...       ...                        ...                       ...
# 1160    90141  4.278668            Freak Of Nature     American Imperial IPA
# 1161    92960  4.355447                Yellow Rose              American IPA
# 1162    93400  4.393456  Grassroots Brother Soigné            Belgian Saison
# 1163    94634  4.593338            Atrial Rubicite         American Wild Ale
# 1164    95921  4.064100              Blazing World  American Amber / Red Ale
#
#       brewery_id           brewery_name             city state country  \
# 0              3      Abita Brewing Co.    Abita Springs    LA      US
# 1              3      Abita Brewing Co.    Abita Springs    LA      US
# 2              3      Abita Brewing Co.    Abita Springs    LA      US
# 3              3      Abita Brewing Co.    Abita Springs    LA      US
# 4              3      Abita Brewing Co.    Abita Springs    LA      US
# ...          ...                    ...              ...   ...     ...
# 1160       30581    Wicked Weed Brewing        Asheville    NC      US
# 1161       30380  The Lone Pint Brewery         Magnolia    TX      US
# 1162       23205     Grassroots Brewing  Greensboro Bend    VT      US
# 1163       24018    Jester King Brewery           Austin    TX      US
# 1164       31987      Modern Times Beer        San Diego    CA      US
#
#                                        beer_brewery
# 0                          Amber- Abita Brewing Co.
# 1                       Turbodog- Abita Brewing Co.
# 2                    Purple Haze- Abita Brewing Co.
# 3                      Andygator- Abita Brewing Co.
# 4                    Jockamo IPA- Abita Brewing Co.
# ...                                             ...
# 1160           Freak Of Nature- Wicked Weed Brewing
# 1161             Yellow Rose- The Lone Pint Brewery
# 1162  Grassroots Brother Soigné- Grassroots Brewing
# 1163           Atrial Rubicite- Jester King Brewery
# 1164               Blazing World- Modern Times Beer
#
# [1165 rows x 10 columns]
